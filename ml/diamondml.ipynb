# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mat
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
diamond_data = pd.read_excel("cleaned_data2.xlsx")
diamond_data
# Out:
#        Unnamed: 0  price  carat        cut color clarity  depth  table     x  \
# 0               0    326   0.23      Ideal     E     SI2   61.5   55.0  3.95
# 1               1    326   0.21    Premium     E     SI1   59.8   61.0  3.89
# 2               2    327   0.23       Good     E     VS1   56.9   65.0  4.05
# 3               3    334   0.29    Premium     I     VS2   62.4   58.0  4.20
# 4               4    335   0.31       Good     J     SI2   63.3   58.0  4.34
# ...           ...    ...    ...        ...   ...     ...    ...    ...   ...
# 53789       53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75
# 53790       53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69
# 53791       53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66
# 53792       53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15
# 53793       53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53789  5.76  3.50
# 53790  5.75  3.61
# 53791  5.68  3.56
# 53792  6.12  3.74
# 53793  5.87  3.64
#
# [53794 rows x 11 columns]

# %%
diamond_data.describe()
# Out:
#          Unnamed: 0         price        carat         depth         table  \
# count  53794.000000  53794.000000  53794.00000  53794.000000  53794.000000
# mean   26970.074246   3933.065082      0.79778     61.748167     57.458109
# std    15577.122053   3988.114460      0.47339      1.429763      2.233679
# min        0.000000    326.000000      0.20000     43.000000     43.000000
# 25%    13479.250000    951.000000      0.40000     61.000000     56.000000
# 50%    26959.500000   2401.000000      0.70000     61.800000     57.000000
# 75%    40472.750000   5326.750000      1.04000     62.500000     59.000000
# max    53939.000000  18823.000000      5.01000     79.000000     95.000000
#
#                   x             y             z
# count  53794.000000  53794.000000  53794.000000
# mean       5.731214      5.734653      3.538714
# std        1.120695      1.141209      0.705037
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.030000
# max       10.740000     58.900000     31.800000

# %%
cont_data= diamond_data.select_dtypes(exclude='object')
cont_data
# Out:
#        Unnamed: 0  price  carat  depth  table     x     y     z
# 0               0    326   0.23   61.5   55.0  3.95  3.98  2.43
# 1               1    326   0.21   59.8   61.0  3.89  3.84  2.31
# 2               2    327   0.23   56.9   65.0  4.05  4.07  2.31
# 3               3    334   0.29   62.4   58.0  4.20  4.23  2.63
# 4               4    335   0.31   63.3   58.0  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53789       53935   2757   0.72   60.8   57.0  5.75  5.76  3.50
# 53790       53936   2757   0.72   63.1   55.0  5.69  5.75  3.61
# 53791       53937   2757   0.70   62.8   60.0  5.66  5.68  3.56
# 53792       53938   2757   0.86   61.0   58.0  6.15  6.12  3.74
# 53793       53939   2757   0.75   62.2   55.0  5.83  5.87  3.64
#
# [53794 rows x 8 columns]

# %%
#visualizing the dataset
#visualising the corelation


# Computing the correlation matrix
corr_matrix = cont_data.corr()

# Printing the correlation matrix
print(corr_matrix)

# Creating a heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
# Out:
#             Unnamed: 0     price     carat     depth     table         x  \
# Unnamed: 0    1.000000 -0.306898 -0.378004 -0.035398 -0.100819 -0.405212
# price        -0.306898  1.000000  0.921548 -0.011051  0.126566  0.884504
# carat        -0.378004  0.921548  1.000000  0.027879  0.181091  0.975380
# depth        -0.035398 -0.011051  0.027879  1.000000 -0.297556 -0.025305
# table        -0.100819  0.126566  0.181091 -0.297556  1.000000  0.194855
# x            -0.405212  0.884504  0.975380 -0.025305  0.194855  1.000000
# y            -0.395580  0.865395  0.951908 -0.029346  0.183231  0.974592
# z            -0.399022  0.861208  0.953542  0.094790  0.150270  0.970686
#
#                    y         z
# Unnamed: 0 -0.395580 -0.399022
# price       0.865395  0.861208
# carat       0.951908  0.953542
# depth      -0.029346  0.094790
# table       0.183231  0.150270
# x           0.974592  0.970686
# y           1.000000  0.951844
# z           0.951844  1.000000
# <Axes: >

# %%
diamond_data.dtypes
# Out:
# Unnamed: 0      int64
# price           int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
diamond_data.describe(include='all')
# Out:
#           Unnamed: 0         price        carat    cut  color clarity  \
# count   53794.000000  53794.000000  53794.00000  53794  53794   53794
# unique           NaN           NaN          NaN      5      7       8
# top              NaN           NaN          NaN  Ideal      G     SI1
# freq             NaN           NaN          NaN  21488  11262   13032
# mean    26970.074246   3933.065082      0.79778    NaN    NaN     NaN
# std     15577.122053   3988.114460      0.47339    NaN    NaN     NaN
# min         0.000000    326.000000      0.20000    NaN    NaN     NaN
# 25%     13479.250000    951.000000      0.40000    NaN    NaN     NaN
# 50%     26959.500000   2401.000000      0.70000    NaN    NaN     NaN
# 75%     40472.750000   5326.750000      1.04000    NaN    NaN     NaN
# max     53939.000000  18823.000000      5.01000    NaN    NaN     NaN
#
#                depth         table             x             y             z
# count   53794.000000  53794.000000  53794.000000  53794.000000  53794.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       61.748167     57.458109      5.731214      5.734653      3.538714
# std         1.429763      2.233679      1.120695      1.141209      0.705037
# min        43.000000     43.000000      0.000000      0.000000      0.000000
# 25%        61.000000     56.000000      4.710000      4.720000      2.910000
# 50%        61.800000     57.000000      5.700000      5.710000      3.530000
# 75%        62.500000     59.000000      6.540000      6.540000      4.030000
# max        79.000000     95.000000     10.740000     58.900000     31.800000
